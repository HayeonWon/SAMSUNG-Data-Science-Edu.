# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

class disp(object):
    template = '<div style="float: left;padding:10px;"> <b>[{0}]</b> {1}</div>'
    def __init__(self, *args):
        self.args = args
        
    def _repr_html_(self):
        return '\n'.join(self.template.format(a, eval(a)._repr_html_())
                         for a in self.args)

import pandas as pd

# %% [markdown]
# * append : **행** 방향으로 **연결**
# * concat : **행과 열** 방향으로 **연결**
# * join : **동일 index**로 **컬럼 병합**
# * merge : **동일 컬럼**으로 **컬럼 병합**

# %% [markdown]
# ### [예제1] append() 메서드의 이해

# %% [markdown]
# * append는 무조건 행 방향으로만 연결함 (axis 설정 없음)

# %%
df1 = pd.DataFrame({'X':list('ABC'), 'Y':[10, 20, 30]})
df2 = pd.DataFrame({'Y':[40, 50], 'X':list('DE')})

r1 = df1.append(df2)

disp('df1', 'df2', 'r1')
# Out:
# C:\Users\dsa.sec\AppData\Local\Temp\ipykernel_17368\3816519278.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   r1 = df1.append(df2)
# <div style="float: left;padding:10px;"> <b>[df1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>B</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C</td>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[df2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Y</th>
#       <th>X</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>40</td>
#       <td>D</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>50</td>
#       <td>E</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>B</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C</td>
#       <td>30</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>D</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>E</td>
#       <td>50</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
df1 = pd.DataFrame({'X':list('ABC'), 'Y':[10, 20, 30]})
df2 = pd.DataFrame({'Y':[40, 50], 'X':list('DE')})
df3 = pd.DataFrame({'X':list('FG'), 'Y':[60, 70]})

r2 = df1.append([df2, df3])

disp('df1', 'df2', 'df3', 'r2')

# %%
df1 = pd.DataFrame({'X':list('ABC'), 'Y':[10, 20, 30]})
df2 = pd.DataFrame({'Y':[40, 50], 'X':list('DE')})
df3 = pd.DataFrame({'X':list('FG'), 'Y':[60, 70]})

r3 = df1.append([df2.loc[1], df3.loc[1]])

disp('df1', 'df2', 'df3', 'r3')

# %% [markdown]
# 행 방향으로 연결(append)하고, 빈 값들은 NaN 처리

# %%
df1 = pd.DataFrame({'X':list('ABC'), 'Y':[10, 20, 30]})
df4 = pd.DataFrame({'X':list('DEF'), 'Z':[100,200,300]})

r4 = df1.append(df4)
# r5 = df1.append(df4, verify_integrity=True) #error

disp('df1', 'df4', 'r4')
# Out:
# C:\Users\dsa.sec\AppData\Local\Temp\ipykernel_17368\1521873255.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   r4 = df1.append(df4)
# <div style="float: left;padding:10px;"> <b>[df1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>B</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C</td>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[df4]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>D</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>E</td>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>F</td>
#       <td>300</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r4]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>10.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>B</td>
#       <td>20.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C</td>
#       <td>30.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>D</td>
#       <td>NaN</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>E</td>
#       <td>NaN</td>
#       <td>200.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>F</td>
#       <td>NaN</td>
#       <td>300.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %% [markdown]
# ### [예제2] append() 메서드의 이해2

# %%
# [1-1]

df1 = pd.DataFrame({'Y':[10, 20, 30], 'X':list('ABC')}, index=[1,2,3])
df2 = pd.DataFrame({'X':list('DE'), 'Z':[100,200]}, index=[1,2])

r1 = df1.append(df2, ignore_index=True)

disp('df1', 'df2', 'r1')

# %%
# [1-2]

df1 = pd.DataFrame({'Y':[10, 20, 30], 'X':list('ABC')}, index=[1,2,3])
df2 = pd.DataFrame({'X':list('DE'), 'Z':[100,200]}, index=[1,2])

r2 = df1.append(df2, sort=True)

disp('df1', 'df2', 'r2')

# %%
# [1-3]

df1 = pd.DataFrame({'Y':[10, 20, 30], 'X':list('ABC')}, index=[1,2,3])
df2 = pd.DataFrame({'X':list('DE'), 'Z':[100,200]}, index=[1,2])

r3 = df2.append({'X':'F', 'Z':300}, ignore_index=True)

disp('df1', 'df2', 'r3')

# %%
# [2]

df1 = pd.DataFrame({'Y':[10, 20, 30], 'X':list('ABC')}, index=[1,2,3])
df2 = pd.DataFrame({'X':list('DE'), 'Z':[100,200]}, index=[1,2])

r4 = df1['X'].append(df2['Z'])
r5 = df1.loc[1].append(df2.loc[2]) #?

r4; r5

# %% [markdown]
# ### [예제3] concat() 함수

# %% [markdown]
# * concat은 행과 열 방향으로 연결
# * 행 방향이 default
# * 열 방향으로 연결할 때, 동일 index로 연결

# %%
df1 = pd.DataFrame({'exam':[80,50]}, index=['kim','lee'])
df2 = pd.DataFrame({'hw':['Y','N']}, index=['lee','kim'])
disp('df1', 'df2')

r1 = pd.concat([df1['exam'], df2['hw']])          # 행 방향으로 연결
r2 = pd.concat([df1['exam'], df2['hw']], axis=1)  # 열 방향으로 연결 (동일 index에 맞춰)
r3 = pd.concat([df1['exam'],df2['hw']],axis=1,keys=['EX','HW']) # keys: label 지정 (axis=1이므로 열label이 됨)
r4 = pd.concat([df1, df2['hw']], axis=1)

r1; disp('r2', 'r3', 'r4')
# Out:
# <div style="float: left;padding:10px;"> <b>[df1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>exam</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>kim</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>lee</th>
#       <td>50</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[df2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>hw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>lee</th>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>kim</th>
#       <td>N</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# kim    80
# lee    50
# lee     Y
# kim     N
# dtype: object
# <div style="float: left;padding:10px;"> <b>[r2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>exam</th>
#       <th>hw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>kim</th>
#       <td>80</td>
#       <td>N</td>
#     </tr>
#     <tr>
#       <th>lee</th>
#       <td>50</td>
#       <td>Y</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r3]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>EX</th>
#       <th>HW</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>kim</th>
#       <td>80</td>
#       <td>N</td>
#     </tr>
#     <tr>
#       <th>lee</th>
#       <td>50</td>
#       <td>Y</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r4]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>exam</th>
#       <th>hw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>kim</th>
#       <td>80</td>
#       <td>N</td>
#     </tr>
#     <tr>
#       <th>lee</th>
#       <td>50</td>
#       <td>Y</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %% [markdown]
# ### [예제4] concat() 메서드의 이해

# %% [markdown]
# * default : join = outer

# %%
# [1]

df1 = pd.DataFrame({'X':list('ABC'), 'Y':[10, 20, 30] }, index=[1,2,3]) # col=X Y, row=1 2 3
df2 = pd.DataFrame({'X':list('DEF'), 'Z':[100,200,300]}, index=[1,3,4]) # col=X Z, row=1 3 4

r1 = pd.concat([df1, df2], axis=1) # 열방향으로 outer join. col=X Y X Z, row=1 2 3 4
r2 = pd.concat([df1, df2])         # 행방향으로 outer join. col=X Y Z, row=1 2 3 1 3 4

disp('df1', 'df2', 'r1', 'r2')
# Out:
# <div style="float: left;padding:10px;"> <b>[df1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>A</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C</td>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[df2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>D</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>E</td>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>F</td>
#       <td>300</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>X</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>A</td>
#       <td>10.0</td>
#       <td>D</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#       <td>20.0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C</td>
#       <td>30.0</td>
#       <td>E</td>
#       <td>200.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>F</td>
#       <td>300.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>A</td>
#       <td>10.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#       <td>20.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C</td>
#       <td>30.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>D</td>
#       <td>NaN</td>
#       <td>100.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>E</td>
#       <td>NaN</td>
#       <td>200.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>F</td>
#       <td>NaN</td>
#       <td>300.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
# [2]

df1 = pd.DataFrame({'X':list('ABC'), 'Y':[10, 20, 30] }, index=[1,2,3])
df2 = pd.DataFrame({'X':list('DEF'), 'Z':[100,200,300]}, index=[1,3,4])

r3 = pd.concat([df1, df2], axis=1, join='inner')            # 열방향으로 연결하되, 동일 index만 남김
r4 = pd.concat([df1, df2], join='inner',keys=['DF1','DF2']) # 행방향으로 연결하되, 동일 column만 남김

disp('df1', 'df2', 'r3', 'r4')
# Out:
# <div style="float: left;padding:10px;"> <b>[df1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>A</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C</td>
#       <td>30</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[df2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>D</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>E</td>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>F</td>
#       <td>300</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r3]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>X</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>A</td>
#       <td>10</td>
#       <td>D</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C</td>
#       <td>30</td>
#       <td>E</td>
#       <td>200</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r4]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>X</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="3" valign="top">DF1</th>
#       <th>1</th>
#       <td>A</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C</td>
#     </tr>
#     <tr>
#       <th rowspan="3" valign="top">DF2</th>
#       <th>1</th>
#       <td>D</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>E</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>F</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %% [markdown]
# ### [예제5] join()  메서드의 이해

# %% [markdown]
# * join은 동일 index로 컬럼 병합

# %%
# how='left'가 default (left index를 기준으로 join)

L = pd.DataFrame({'X':list('AB'), 'Y':[10, 20] }, index=[1,2])
R = pd.DataFrame({'X':list('CD'), 'Z':[100,200]}, index=[2,3])

# r1 = L.join(R) # error
r2 = L.join(R, lsuffix='_L', rsuffix='_R') # L에 R을 left join (동일 index만 남기고 컬럼 병합)
r3 = L.join(R, lsuffix='_L', how='right')  # L에 R을 right join

disp('L', 'R', 'r2', 'r3')
# Out:
# <div style="float: left;padding:10px;"> <b>[L]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>A</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#       <td>20</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[R]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>C</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>D</td>
#       <td>200</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X_L</th>
#       <th>Y</th>
#       <th>X_R</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>A</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#       <td>20</td>
#       <td>C</td>
#       <td>100.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r3]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X_L</th>
#       <th>Y</th>
#       <th>X</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>B</td>
#       <td>20.0</td>
#       <td>C</td>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>D</td>
#       <td>200</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %% [markdown]
# ### [예제6] join() : how와 on 옵션 이해

# %%
# [1]

L = pd.DataFrame({'X':list('AB'), 'Y':[10, 20] }).set_index('X')
R = pd.DataFrame({'X':list('BC'), 'Z':[200,300]}).set_index('X')

r1 = L.join(R, how='inner')  # L에 R을 inner join (B 인덱스만 남김)
r2 = L.join(R, how='outer')  # L에 R을 outer join (A,B,C 인덱스 모두)

disp('L', 'R','r1', 'r2')
# Out:
# <div style="float: left;padding:10px;"> <b>[L]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Y</th>
#     </tr>
#     <tr>
#       <th>X</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>20</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[R]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Z</th>
#     </tr>
#     <tr>
#       <th>X</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>B</th>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>300</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Y</th>
#       <th>Z</th>
#     </tr>
#     <tr>
#       <th>X</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>B</th>
#       <td>20</td>
#       <td>200</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Y</th>
#       <th>Z</th>
#     </tr>
#     <tr>
#       <th>X</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>10.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>20.0</td>
#       <td>200.0</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>NaN</td>
#       <td>300.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
# [2]

L2 = pd.DataFrame({'X':list('AB'), 'Y':[10, 20] })
R = pd.DataFrame({'X':list('BC'), 'Z':[200,300]}).set_index('X')

r3 = L2.join(R, how='outer')         # 기본 인덱스로 outer join
r4 = L2.join(R, on='X', how='outer') # X 컬럼을 인덱스로 outer join
r5 = L2.join(R, on='X', how='inner') # X 컬럼을 인덱스로 inner join

disp('L2', 'R'); disp('r3', 'r4', 'r5')
# Out:
# <div style="float: left;padding:10px;"> <b>[L2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>B</td>
#       <td>20</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[R]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Z</th>
#     </tr>
#     <tr>
#       <th>X</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>B</th>
#       <td>200</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>300</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r3]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>A</td>
#       <td>10.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>B</td>
#       <td>20.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>200.0</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>300.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r4]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0.0</th>
#       <td>A</td>
#       <td>10.0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1.0</th>
#       <td>B</td>
#       <td>20.0</td>
#       <td>200.0</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>C</td>
#       <td>NaN</td>
#       <td>300.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r5]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>X</th>
#       <th>Y</th>
#       <th>Z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>B</td>
#       <td>20</td>
#       <td>200</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %% [markdown]
# ### [예제7] merge() 함수의 이해 1

# %% [markdown]
# * merge : 동일 컬럼으로 컬럼 병합

# %%
# [1]
# 공통 컬럼을 기준으로 컬럼 병합
# how='inner'가 default

n = ['kim','lee','park']
L = pd.DataFrame({'name': n,'id': [100,101,102],'exam':[70,80,90]}, index = list('ABC'))
R = pd.DataFrame({'name': n,'id': [100,201,102],'hw':['Y','N','N']}, index = list('XYZ'))
disp('L', 'R')

r1 = pd.merge(L, R)                # L과 R의 공통 컬럼(name, id)에서 값이 일치하는 인덱스로만 merge
r2 = L.merge(R)                    # 위와 같음
r3 = L.merge(R, on=['name', 'id']) # 위와 같음
r4 = L.merge(R, on='id')           # id 컬럼만을 기준으로 merge

disp('r1', 'r2', 'r3', 'r4')
# Out:
# <div style="float: left;padding:10px;"> <b>[L]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>id</th>
#       <th>exam</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>kim</td>
#       <td>100</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>lee</td>
#       <td>101</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>park</td>
#       <td>102</td>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[R]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>id</th>
#       <th>hw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>X</th>
#       <td>kim</td>
#       <td>100</td>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>Y</th>
#       <td>lee</td>
#       <td>201</td>
#       <td>N</td>
#     </tr>
#     <tr>
#       <th>Z</th>
#       <td>park</td>
#       <td>102</td>
#       <td>N</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>id</th>
#       <th>exam</th>
#       <th>hw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>kim</td>
#       <td>100</td>
#       <td>70</td>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>park</td>
#       <td>102</td>
#       <td>90</td>
#       <td>N</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>id</th>
#       <th>exam</th>
#       <th>hw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>kim</td>
#       <td>100</td>
#       <td>70</td>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>park</td>
#       <td>102</td>
#       <td>90</td>
#       <td>N</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r3]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>id</th>
#       <th>exam</th>
#       <th>hw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>kim</td>
#       <td>100</td>
#       <td>70</td>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>park</td>
#       <td>102</td>
#       <td>90</td>
#       <td>N</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r4]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name_x</th>
#       <th>id</th>
#       <th>exam</th>
#       <th>name_y</th>
#       <th>hw</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>kim</td>
#       <td>100</td>
#       <td>70</td>
#       <td>kim</td>
#       <td>Y</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>park</td>
#       <td>102</td>
#       <td>90</td>
#       <td>park</td>
#       <td>N</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
# [2]

n = ['kim','lee','park']
L = pd.DataFrame({'name': n,'id': [100,101,102],'exam':[70,80,90]}, index = list('ABC'))
R = pd.DataFrame({'name': n,'id': [100,201,102],'hw':['Y','N','N']}, index = list('XYZ'))
disp('L', 'R')

r5 = L.merge(R, how='left')   # col=name id exam hw, row=0 1 2 (L에 hw 병합하면서 없는 값은 nan)
r6 = L.merge(R, how='right')  # col=name id exam hw, row=0 1 2 (R에 exam 병합하면서 없는 값은 nan)
r7 = L.merge(R, how='outer')  # col=name id exam hw, row=0 1 2 3 (exam과 hw 병합하면서 없는 값 nan)

disp('r5', 'r6', 'r7')

# %% [markdown]
# ### [예제8] merge() 함수의 이해 2

# %%
# [1]
# left_index, right_index : 왼쪽, 오른쪽 객체의 기본 index를 merge key로 사용할지 여부 (default: False) 

L = pd.DataFrame({'id':[100,101,102],'name':['kim','lee','park']}, index = list('ABC'))
R = pd.DataFrame({'exam':[70,80,90], 'id':[100,201,102]}).set_index('id')
disp('L', 'R')

r1 = pd.merge(L,R,left_on='id', right_index=True)              # R의 index(=id)를 merge key로 활용하고, id 컬럼을 기준으로 inner merge
r2 = pd.merge(L,R,left_on='id', right_index=True, how='left')  # left merge
r3 = pd.merge(L,R,left_on='id', right_index=True, how='right') # right merge
r4 = pd.merge(L,R,left_on='id', right_index=True, how='outer') # outer merge

disp('r1','r2', 'r3', 'r4')
# Out:
# <div style="float: left;padding:10px;"> <b>[L]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>100</td>
#       <td>kim</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>101</td>
#       <td>lee</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>102</td>
#       <td>park</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[R]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>exam</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>100</th>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>201</th>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>exam</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>100</td>
#       <td>kim</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>102</td>
#       <td>park</td>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>exam</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>100</td>
#       <td>kim</td>
#       <td>70.0</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>101</td>
#       <td>lee</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>102</td>
#       <td>park</td>
#       <td>90.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r3]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>exam</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>100</td>
#       <td>kim</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>201</td>
#       <td>NaN</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>102</td>
#       <td>park</td>
#       <td>90</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r4]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>exam</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>100</td>
#       <td>kim</td>
#       <td>70.0</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>101</td>
#       <td>lee</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>102</td>
#       <td>park</td>
#       <td>90.0</td>
#     </tr>
#     <tr>
#       <th>NaN</th>
#       <td>201</td>
#       <td>NaN</td>
#       <td>80.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
# [2]

L = pd.DataFrame({'id':[100,101,102],'name':['kim','lee','park']}, index = list('ABC'))
R = pd.DataFrame({'exam':[70,80,90], 'id':[100,201,102]}).set_index('id')
disp('L', 'R')

r5 = L.join(R, on='id')
dic = {'exam':0, 'name':'-'}
r6 = L.join(R, on='id', how='outer').reset_index(drop=True).fillna(dic)

disp('r5', 'r6')

# %% [markdown]
# ### [예제9]  merge()함수에서 일대다, 다대다 관계 이해

# %%
# [1]

L = pd.DataFrame({'id':[100,101,102],'name':['kim','lee','park']}, index = list('ABC'))
R = pd.DataFrame({'id':[100,100,102],'subject':['kor','eng','kor']}, index = list('XYZ'))

r1 = L.merge(R) # 새로운 index 부여
r2 = L.join(R.set_index('id'), on='id', how='inner') # R의 index인 id가 key컬럼으로 활용되면, L의 index(A,B,C) 그대로 가져감

disp('L', 'R', 'r1', 'r2')
# Out:
# <div style="float: left;padding:10px;"> <b>[L]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>100</td>
#       <td>kim</td>
#     </tr>
#     <tr>
#       <th>B</th>
#       <td>101</td>
#       <td>lee</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>102</td>
#       <td>park</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[R]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>subject</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>X</th>
#       <td>100</td>
#       <td>kor</td>
#     </tr>
#     <tr>
#       <th>Y</th>
#       <td>100</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>Z</th>
#       <td>102</td>
#       <td>kor</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r1]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>subject</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>100</td>
#       <td>kim</td>
#       <td>kor</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>100</td>
#       <td>kim</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>102</td>
#       <td>park</td>
#       <td>kor</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
# <div style="float: left;padding:10px;"> <b>[r2]</b> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>subject</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>A</th>
#       <td>100</td>
#       <td>kim</td>
#       <td>kor</td>
#     </tr>
#     <tr>
#       <th>A</th>
#       <td>100</td>
#       <td>kim</td>
#       <td>eng</td>
#     </tr>
#     <tr>
#       <th>C</th>
#       <td>102</td>
#       <td>park</td>
#       <td>kor</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
# [2]

L2 = pd.DataFrame({'id':[100,100,102],'subject':['kor','eng','kor']}, index = list('ABC'))
R2 = pd.DataFrame({'id':[100,100,102],'exam':['mid','final','mid'],'pct':[0.4,0.6,1]}, index = list('XYZ'))

r3 = L2.merge(R2)
r4 = L2.join(R2.set_index('id'), on='id', how='inner').reset_index(drop=True)

disp('L2', 'R2', 'r3', 'r4')

# %% [markdown]
# ### [예제10] merge() 활용 예

# %%
# [1]

# 성적 결과
d1 = {'id':[100,100,300],'code':['C1','C2','C2'],'score':[100,80,60]}
df1 = pd.DataFrame(d1)

# 학생 명단 정보
i1 = {'id':[100,200,300], 'names':['kim', 'lee', 'park']}
in1 = pd.DataFrame(i1)

# 과목 코드 정보
i2 = {'code':['C1', 'C2','C3'],'subject':['kor', 'eng', 'math']}
in2 = pd.DataFrame(i2)

exam_df = df1.merge(in1).merge(in2)
disp('df1', 'in1', 'in2'); exam_df

# %%
# [2]

# 성적 결과
d1 = {'id':[100,100,300],'code':['C1','C2','C2'],'score':[100,80,60]}
df1 = pd.DataFrame(d1)

# 과제 제출 명단
d2 = {'id':[100,200,300], 'code':['C1','C1','C2'],'hw_date':['05-01','05-03','05-05']}
df2 = pd.DataFrame(d2)

hw_df = df1.merge(df2, how='right')
disp('df1', 'df2', 'hw_df')
